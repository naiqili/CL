# %%
import torch
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
from ExtCIFAR10 import ExtCIFAR10

root = 'd:\Lab\dataset'

transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

testset = ExtCIFAR10(root=root, train=False, download=False, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=32,
                                          shuffle=True, num_workers=2)

# %%
def imshow(img):
    npimg = img.numpy()
    npimg = npimg / 2 + 0.5     # unnormalize
    plt.figure(figsize=(10,10))
    plt.imshow(np.transpose(npimg, (1, 2, 0)))


classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# get some random training images
dataiter = iter(testloader)
idxs, images, labels = dataiter.next()

# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(32)))
print(images[0].shape)
print(idxs)
# Out:
#   car  deer   car  deer plane horse  deer  ship  bird horse   cat   car plane   cat   cat   cat   dog horse horse   car truck  frog  ship  frog horse  frog  frog   cat  ship plane  ship plane
# torch.Size([3, 32, 32])
# tensor([6991, 9104, 5386, 4117,  496, 2908, 9972, 6295, 8987, 2640, 6792, 1270,
#          581, 2646, 3298, 5689, 6562, 5965, 4281, 3661, 9500, 5174,  717, 7667,
#         6390, 6520, 6801, 7212, 5946, 4328, 3886, 3211])

# %%
b_size = 4096

trainset = ExtCIFAR10(root=root, train=True, download=False, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=b_size,
                                          shuffle=True, num_workers=2)
